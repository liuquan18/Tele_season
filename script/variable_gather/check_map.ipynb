# %%
import xarray as xr

# %%
ex = xr.open_dataset("/work/mh0033/m300883/3rdPanel/data/influence/t2min/exp.nc")

# %%
ex
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 12, lon: 192, lat: 96)
# Coordinates:
#   * time     (time) float64 1.991e+07 1.991e+07 ... 1.991e+07 1.991e+07
#   * lon      (lon) float64 0.0 1.875 3.75 5.625 7.5 ... 352.5 354.4 356.2 358.1
#   * lat      (lat) float64 88.57 86.72 84.86 83.0 ... -83.0 -84.86 -86.72 -88.57
# Data variables:
#     var201   (time, lat, lon) float32 ...
#     var202   (time, lat, lon) float32 ...
# Attributes:
#     CDI:                       Climate Data Interface version 2.0.6 (https://...
#     Conventions:               CF-1.6
#     institution:               Max Planck Institute for Meteorology
#     history:                   Mon Dec 19 14:43:16 2022: cdo -f nc -P 48 -sel...
#     CDO:                       Climate Data Operators version 2.0.6 (https://...
#     cdo_openmp_thread_number:  48

# %%
ex.isel(time = 0).var202.plot()

# %%
ex.isel(time = 0).var202.mean()
# Out:
# <xarray.DataArray 'var202' ()>
# array(278.47372, dtype=float32)
# Coordinates:
#     time     float64 1.991e+07

# %%
ex.isel(time = 0).var201.mean()
# Out:
# <xarray.DataArray 'var201' ()>
# array(286.11215, dtype=float32)
# Coordinates:
#     time     float64 1.991e+07

# %%
ex.isel(time = 0).var201.plot()
